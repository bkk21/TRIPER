# %%
#이름이랑 별점만 크롤링
import json
import time
from time import sleep
import csv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

def search_food(key):
    
    cafe_list = []
    
    url = 'https://map.naver.com/v5/search'
    driver = webdriver.Chrome()  # 드라이버
    driver.get(url)
    key_word = "서울" + key + ' 놀거리'  # 검색어

    # css 찾을때 까지 10초대기
    def time_wait(num, code):
        try:
            wait = WebDriverWait(driver, num).until(
                EC.presence_of_element_located((By.CSS_SELECTOR, code)))
        except:
            print(code, '태그를 찾지 못하였습니다.')
            driver.quit()
        return wait

    # frame 변경 메소드
    def switch_frame(frame):
        driver.switch_to.default_content()  # frame 초기화
        driver.switch_to.frame(frame)  # frame 변경

    # 페이지 다운
    def page_down(num):
        body = driver.find_element(By.CSS_SELECTOR, 'body')
        body.click()
        for i in range(num):
            body.send_keys(Keys.PAGE_DOWN)

    # css를 찾을때 까지 10초 대기
    time_wait(10, 'div.input_box > input.input_search')

    # (1) 검색창 찾기
    search = driver.find_element(By.CSS_SELECTOR, 'div.input_box > input.input_search')
    search.send_keys(key_word)  # 검색어 입력
    search.send_keys(Keys.ENTER)  # 엔터버튼 누르기

    sleep(1)

    # (2) frame 변경
    switch_frame('searchIframe')
    page_down(40)
    sleep(3)

    # 가게 리스트
    shop_list = driver.find_elements(By.CSS_SELECTOR, 'li.S0Ns3')
    # 페이지 리스트
    next_btn = driver.find_elements(By.CSS_SELECTOR, '.zRM9F> a')

    # dictionary 생성
    shop_dict = {'가게정보': []}
    # 시작시간
    start = time.time()
    print('[크롤링 시작...]')
    
    print(shop_list)

    # 크롤링 (페이지 리스트 만큼)
    for btn in range(len(next_btn))[1:]:  # next_btn[0] = 이전 페이지 버튼 무시 -> [1]부터 시작
        parking_list = driver.find_elements(By.CSS_SELECTOR, 'li.S0Ns3')
        names = driver.find_elements(By.CSS_SELECTOR, '.xBZDS')  # (3) 장소명
        types = driver.find_elements(By.CSS_SELECTOR, '.LF32u')  # (4) 장소 유형

        for data in range(len(shop_list)):  # 가게 리스트 만큼
            print(data)
            
            #real_star = star[data].text
            #real_star = str(real_star).split("\n")[1]
            #print(real_star)
            #if float(real_star) < 4.3:
            #    continue

            sleep(1)
            try:

                # (3) 가게명 가져오기
                shop_name = str(names[data].text)
                print(shop_name)

                # (4) 유형
                shop_type = str(types[data].text)
                print(shop_type)
                
                #(5) 별점
                #real_star = star[data].text
                #real_star = str(real_star).split("\n")[1]
                #print(real_star)
                
                tmp = [shop_name]
                cafe_list.append(tmp)
                
                print(f'{shop_name} ...완료')

                sleep(1)

            except Exception as e:
                print(e)
                print('ERROR!' * 3)

                sleep(1)

        # 다음 페이지 버튼 누를 수 없으면 종료
        if not next_btn[-1].is_enabled():
            break

        if names[-1]:  # 마지막이면 다음버튼 클릭
            next_btn[-1].click()

            sleep(2)

        else:
            print('페이지 인식 못함')
            break

    print('[데이터 수집 완료]\n소요 시간 :', time.time() - start)
    driver.quit()  # 작업이 끝나면 창을 닫는다.

    index_final = len(cafe_list) // 2
    cafe_list = cafe_list[0:index_final]
    
    return cafe_list

##############################################################################

regions = ["종로구", "중구", "용산구", "성동구", "광진구", "동대문구", "중랑구", "성북구", "강북구", "도봉구", "노원구", "은평구", "서대문구", "마포구", "양천구", 
           "강서구", "구로구", "금천구", "영등포구", "동작구", "관악구", "서초구", "강남구", "송파구", "강동구"]

    
##1, 2 // 15, 16
for i in range(15, 16):
    filename = "./out_play/out_" + str(i) + "_play.csv"
    f = open(filename, 'w', encoding='utf-8', newline='')
    writer = csv.writer(f)
    writer.writerows(search_food(regions[i]))
    f.close()
# Out:
# The chromedriver version (128.0.6613.137) detected in PATH at c:\Users\kk21\Desktop\TRIPER\chromedriver.exe might not be compatible with the detected chrome version (129.0.6668.90); currently, chromedriver 129.0.6668.91 is recommended for chrome 129.*, so it is advised to delete the driver in PATH and retry
# [크롤링 시작...]
# [<selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.143")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.115")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.120")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.144")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.145")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.146")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.147")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.148")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.149")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.150")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.151")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.152")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.153")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.154")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.155")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.156")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.157")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.158")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.159")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.160")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD892262AD39B075898F848.e.161")>, <selenium.webdriver.remote.webelement.WebElement (session="10c21551368b5b36c2d0830e2a9660b0", element="f.B143949E3D13D30A1875F96978C28ED1.d.E200EFE57DD89226 ...
# 0
# 서울식물원
# 식물원,수목원
# 서울식물원 ...완료
# 1
# 국립항공박물관
# 박물관
# 국립항공박물관 ...완료
# 2
# 스위트파크 롯데 어린이 식품체험관
# 체험,홍보관
# 스위트파크 롯데 어린이 식품체험관 ...완료
# 3
# 플레이스콤마
# 관광농원,팜스테이
# 플레이스콤마 ...완료
# 4
# 기생충박물관
# 박물관
# 기생충박물관 ...완료
# 5
# 김포공항국내선청사공항전망대
# 전망대
# 김포공항국내선청사공항전망대 ...완료
# 6
# 강서별빛우주과학관
# 과학관
# 강서별빛우주과학관 ...완료
# 7
# 서울물재생체험관
# 관람,체험
# 서울물재생체험관 ...완료
# 8
# 방화근린공원
# 근린공원
# 방화근린공원 ...완료
# 9
# 구암근린공원
# 근린공원
# 구암근린공원 ...완료
# 10
# 강서 한강공원
# 시민공원
# 강서 한강공원 ...완료
# 11
# 허준박물관
# 박물관
# 허준박물관 ...완료
# 12
# 궁산근린공원
# 근린공원
# 궁산근린공원 ...완료
# 13
# 마곡나루근린공원
# 근린공원
# 마곡나루근린공원 ...완료
# 14
# 마곡광장
# 근린공원
# 마곡광장 ...완료
# 15
# 서울물재생공원
# 시민공원
# 서울물재생공원 ...완료
# 16
# 우장산공원
# 근린공원
# 우장산공원 ...완료
# 17
# 강서구 오곡텃밭
# 주말농장
# 강서구 오곡텃밭 ...완료
# 18
# 봉제산
# 산
# 봉제산 ...완료
# 19
# 까치산근린공원
# 근린공원
# 까치산근린공원 ...완료
# 20
# 강서한강공원강서습지생태공원
# 자연,생태공원
# 강서한강공원강서습지생태공원 ...완료
# 21
# 서남물재생센터공원
# 근린공원
# 서남물재생센터공원 ...완료
# 22
# 양천향교
# 문화,유적
# 양천향교 ...완료
# 23
# 우장근린공원 힐링체험센터
# 관람,체험
# 우장근린공원 힐링체험센터 ...완료
# 24
# 발산근린공원
# 근린공원
# 발산근린공원 ...완료
# 25
# 습지생태공원
# 자연,생태공원
# 습지생태공원 ...완료
# 26
# 서울식물원습지원
# 자연공원
# 서울식물원습지원 ...완료
# 27
# 봉제산근린공원
# 근린공원
# 봉제산근린공원 ...완료
# 28
# 마곡하늬공원
# 근린공원
# 마곡하늬공원 ...완료
# 29
# 원당근린공원
# 근린공원
# 원당근린공원 ...완료
# 30
# 수명산
# 산
# 수명산 ...완료
# 31
# 궁산
# 산
# 궁산 ...완료
# 32
# 롯데몰 김포공항점스카이파크
# 도시,테마공원
# 롯데몰 김포공항점스카이파크 ...완료
# 33
# 증미산
# 산
# 증미산 ...완료
# 34
# 우장산
# 산
# 우장산 ...완료
# 35
# 황금내근린공원
# 근린공원
# 황금내근린공원 ...완료
# 36
# 개화산
# 산
# 개화산 ...완료
# 37
# 강서구주말농장
# 주말농장
# 강서구주말농장 ...완료
# 38
# 서낭당근린공원
# 근린공원
# 서낭당근린공원 ...완료
# 39
# 수명산근린공원
# 근린공원
# 수명산근린공원 ...완료
# 40
# 가양동문화공원
# 근린공원
# 가양동문화공원 ...완료
# 41
# 어울림공원
# 근린공원
# 어울림공원 ...완료
# 42
# 새싹어린이교통공원
# 근린공원
# 새싹어린이교통공원 ...완료
# 43
# 개화산 호국공원
# 근린공원
# 개화산 호국공원 ...완료
# 44
# 염창소공원
# 근린공원
# 염창소공원 ...완료
# 45
# 봉제산근린공원
# 근린공원
# 봉제산근린공원 ...완료
# 46
# 치현산
# 산
# 치현산 ...완료
# 47
# 검덕산
# 산
# 검덕산 ...완료
# 48
# 허준테마거리
# 문화거리
# 허준테마거리 ...완료
# 49
# 개화산해맞이공원
# 도시,테마공원
# 개화산해맞이공원 ...완료
# 50
# 소악루
# 국가유산
# 소악루 ...완료
# 51
# 허가바위
# 국가유산
# 허가바위 ...완료
# 52
# 양천고성지
# 국가유산
# 양천고성지 ...완료
# 53
# LG아트센터 서울
# 공연장
# LG아트센터 서울 ...완료
# 54
# 오지오커피
# 카페,디저트
# 오지오커피 ...완료
# 55
# 떼헤브
# 카페,디저트
# 떼헤브 ...완료
# 56
# 스페이스K 서울
# 미술관
# 스페이스K 서울 ...완료
# 57
# 베이글리스트
# 카페,디저트
# 베이글리스트 ...완료
# 58
# 경성별하 한복
# 한복대여
# 경성별하 한복 ...완료
# 59
# 우리미한복
# 한복대여
# 우리미한복 ...완료
# 60
# 겸재정선미술관
# 미술관
# 겸재정선미술관 ...완료
# 61
# 베이커리 룬
# 베이커리
# 베이커리 룬 ...완료
# 62
# 인쏘우
# 카페,디저트
# 인쏘우 ...완료
# 63
# 프레베리 마곡케이크
# 카페,디저트
# 프레베리 마곡케이크 ...완료
# 64
# 카페 우드진
# 카페,디저트
# 카페 우드진 ...완료
# 65
# 고드니
# 카페,디저트
# 고드니 ...완료
# 66
# 깅꼬서울
# 카페,디저트
# 깅꼬서울 ...완료
# 67
# 어나더사이드
# 카페,디저트
# 어나더사이드 ...완료
# 68
# 벤의 서재
# 북카페
# 벤의 서재 ...완료
# 69
# 방신전통시장
# 시장
# 방신전통시장 ...완료
# 0
# 루브레드
# 베이커리
# 루브레드 ...완료
# 1
# 타르데마베이커리 우장산
# 베이커리
# 타르데마베이커리 우장산 ...완료
# 2
# 엘리케이커
# 케이크전문
# 엘리케이커 ...완료
# 3
# NC백화점 강서점
# 백화점
# NC백화점 강서점 ...완료
# 4
# 스퍼터
# 카페,디저트
# 스퍼터 ...완료
# 5
# 더 왓에버
# 브런치카페
# 더 왓에버 ...완료
# 6
# 카페 우드진 마곡나루점
# 카페,디저트
# 카페 우드진 마곡나루점 ...완료
# 7
# 우주제빵소
# 카페,디저트
# 우주제빵소 ...완료
# 8
# 올웨이즈 베이글
# 베이커리
# 올웨이즈 베이글 ...완료
# 9
# 치즈당 강서화곡점
# 카페,디저트
# 치즈당 강서화곡점 ...완료
# 10
# 브런치나인
# 브런치카페
# 브런치나인 ...완료
# 11
# 라크루뜨 서울 본점
# 카페,디저트
# 라크루뜨 서울 본점 ...완료
# 12
# 늨늨베이크
# 케이크전문
# 늨늨베이크 ...완료
# 13
# 블리스냅
# 카페
# 블리스냅 ...완료
# 14
# 헤이더그린
# 카페,디저트
# 헤이더그린 ...완료
# 15
# 피코리코 롯데몰 김포공항점
# 카페,디저트
# 피코리코 롯데몰 김포공항점 ...완료
# 16
# 크림토끼 방화역점
# 베이커리
# 크림토끼 방화역점 ...완료
# 17
# 카페 달지
# 카페,디저트
# 카페 달지 ...완료
# 18
# 헤븐온탑 롯데몰김포공항점
# 카페,디저트
# 헤븐온탑 롯데몰김포공항점 ...완료
# 19
# 빵쌤 마곡점
# 베이커리
# 빵쌤 마곡점 ...완료
# 20
# 오프레스트 로스터리
# 카페,디저트
# 오프레스트 로스터리 ...완료
# 21
# 스카이아트홀
# 공연장
# 스카이아트홀 ...완료
# 22
# 브라운씨 2호점
# 카페,디저트
# 브라운씨 2호점 ...완료
# 23
# 수협강서수산물도매시장
# 시장
# 수협강서수산물도매시장 ...완료
# 24
# 달콤하우스
# 베이커리
# 달콤하우스 ...완료
# 25
# 타르데마베이커리 방화본점
# 베이커리
# 타르데마베이커리 방화본점 ...완료
# 26
# 라토레 커피
# 카페,디저트
# 라토레 커피 ...완료
# 27
# 멜랑
# 카페,디저트
# 멜랑 ...완료
# 28
# 오와케이크 마곡역점
# 케이크전문
# 오와케이크 마곡역점 ...완료
# 29
# 남대문커피
# 카페
# 남대문커피 ...완료
# 30
# 인라이크
# 카페,디저트
# 인라이크 ...완료
# 31
# 브레도르
# 케이크전문
# 브레도르 ...완료
# 32
# 비에이
# 카페,디저트
# 비에이 ...완료
# 33
# 도시의숲
# 브런치카페
# 도시의숲 ...완료
# 34
# 광화문살롱
# 베이커리
# 광화문살롱 ...완료
# 35
# 카페 리제르바 마곡
# 카페,디저트
# 카페 리제르바 마곡 ...완료
# 36
# 케이크의 계절
# 케이크전문
# 케이크의 계절 ...완료
# 37
# 희희잇
# 카페,디저트
# 희희잇 ...완료
# 38
# YES24 강서NC점
# 서점
# YES24 강서NC점 ...완료
# 39
# 아이스걸크림보이 마곡점
# 아이스크림
# 아이스걸크림보이 마곡점 ...완료
# 40
# 스타벅스 마곡역점
# 카페
# 스타벅스 마곡역점 ...완료
# 41
# 뉴스페이스
# 전시관
# 뉴스페이스 ...완료
# 42
# 리프
# 카페,디저트
# 리프 ...완료
# 43
# 밀화당 강서직영점
# 베이커리
# 밀화당 강서직영점 ...완료
# 44
# 키릴
# 카페,디저트
# 키릴 ...완료
# 45
# 강서구립가양도서관
# 군구립도서관
# 강서구립가양도서관 ...완료
# 46
# 강서아트리움
# 문화,예술회관
# 강서아트리움 ...완료
# 47
# 소심당
# 베이커리
# 소심당 ...완료
# 48
# 안스베이커리 롯데백화점 김포공항점
# 베이커리
# 안스베이커리 롯데백화점 김포공항점 ...완료
# 49
# 위카페 아임2030 등촌
# 카페,디저트
# 위카페 아임2030 등촌 ...완료
# 50
# 타르데마1942 마곡나루
# 베이커리
# 타르데마1942 마곡나루 ...완료
# 51
# 카페 비플랫
# 카페,디저트
# 카페 비플랫 ...완료
# 52
# 모에뜨
# 베이커리
# 모에뜨 ...완료
# 53
# 루트205
# 베이커리
# 루트205 ...완료
# 54
# 스타벅스 마곡사이언스타워R점
# 카페
# 스타벅스 마곡사이언스타워R점 ...완료
# 55
# 르뺑블랑
# 베이커리
# 르뺑블랑 ...완료
# 56
# 모스 베이커리 카페
# 카페,디저트
# 모스 베이커리 카페 ...완료
# 57
# 스타벅스 마곡나루공원점
# 카페
# 스타벅스 마곡나루공원점 ...완료
# 58
# 플래브베이커리
# 베이커리
# 플래브베이커리 ...완료
# 59
# 스타벅스 김포공항DT점
# 카페
# 스타벅스 김포공항DT점 ...완료
# 60
# 스타벅스 화곡DT점
# 카페
# 스타벅스 화곡DT점 ...완료
# 61
# 브라운씨 1호점
# 카페
# 브라운씨 1호점 ...완료
# 62
# 조선제일빵
# 베이커리
# 조선제일빵 ...완료
# 63
# 올라라
# 베이커리
# 올라라 ...완료
# 64
# 모먼트 인
# 카페,디저트
# 모먼트 인 ...완료
# 65
# 아이키친 마곡점
# 키즈카페,실내놀이터
# 아이키친 마곡점 ...완료
# 66
# 사이유지
# 카페,디저트
# 사이유지 ...완료
# 67
# KBS아레나
# 공연장
# KBS아레나 ...완료
# 68
# 베니르
# 카페,디저트
# 베니르 ...완료
# 69
# 에이바우트커피 양천향교역점
# 카페
# 에이바우트커피 양천향교역점 ...완료
# 0
# 케이크오클락
# 케이크전문
# 케이크오클락 ...완료
# 1
# 슈가파티
# 케이크전문
# 슈가파티 ...완료
# 2
# 파리크라상 이대서울병원점
# 베이커리
# 파리크라상 이대서울병원점 ...완료
# 3
# 스타벅스 마곡나루역점
# 카페
# 스타벅스 마곡나루역점 ...완료
# 4
# 메종드온 한복대여
# 한복대여
# 메종드온 한복대여 ...완료
# 5
# 도깨비베이커리
# 베이커리
# 도깨비베이커리 ...완료
# 6
# 브라이트
# 카페,디저트
# 브라이트 ...완료
# 7
# 스타벅스 발산역점
# 카페
# 스타벅스 발산역점 ...완료
# 8
# 스타벅스 화곡동점
# 카페
# 스타벅스 화곡동점 ...완료
# 9
# 무릭 그릭요거트 마곡본점
# 카페,디저트
# 무릭 그릭요거트 마곡본점 ...완료
# 10
# 퐁퐁
# 카페,디저트
# 퐁퐁 ...완료
# 11
# 212베이크샵
# 카페,디저트
# 212베이크샵 ...완료
# 12
# 강서구립 곰달래도서관
# 도서관
# 강서구립 곰달래도서관 ...완료
# 13
# 브루클린커피
# 카페,디저트
# 브루클린커피 ...완료
# 14
# 루브레드 발산점
# 베이커리
# 루브레드 발산점 ...완료
# 15
# 소카크
# 카페,디저트
# 소카크 ...완료
# 16
# 바이러닉 에스프레소바 마곡점
# 카페,디저트
# 바이러닉 에스프레소바 마곡점 ...완료
# 17
# 카페애크미
# 카페,디저트
# 카페애크미 ...완료
# 18
# 파스쿠찌 김포공항국내선점
# 카페
# 파스쿠찌 김포공항국내선점 ...완료
# 19
# 투썸플레이스 마곡나루역점
# 카페
# 투썸플레이스 마곡나루역점 ...완료
# 20
# 투썸플레이스 마곡점
# 카페
# 투썸플레이스 마곡점 ...완료
# 21
# 맥켄지커피 까치산역본점
# 카페,디저트
# 맥켄지커피 까치산역본점 ...완료
# 22
# 스타벅스 까치산역점
# 카페
# 스타벅스 까치산역점 ...완료
# 23
# 원데잇케이크
# 케이크전문
# 원데잇케이크 ...완료
# 24
# 카페가토
# 카페,디저트
# 카페가토 ...완료
# 25
# 헤리스헤이스
# 카페
# 헤리스헤이스 ...완료
# 26
# 도레도레 롯데몰 김포공항점
# 케이크전문
# 도레도레 롯데몰 김포공항점 ...완료
# 27
# GGNB_Cafe
# 카페,디저트
# GGNB_Cafe ...완료
# 28
# 아로아로 키즈카페
# 키즈카페,실내놀이터
# 아로아로 키즈카페 ...완료
# 29
# 카페 오알
# 카페,디저트
# 카페 오알 ...완료
# 30
# 메가MGC커피 마곡나루역점
# 카페
# 메가MGC커피 마곡나루역점 ...완료
# 31
# 챔피언더블랙벨트 롯데몰 김포공항점
# 키즈카페,실내놀이터
# 챔피언더블랙벨트 롯데몰 김포공항점 ...완료
# 32
# 무키무키 가양점
# 키즈카페,실내놀이터
# 무키무키 가양점 ...완료
# 33
# 강서문화원
# 문화원
# 강서문화원 ...완료
# 34
# 헬로방방 마곡점
# 키즈카페,실내놀이터
# 헬로방방 마곡점 ...완료
# 35
# 시아북카페 마곡점
# 키즈카페,실내놀이터
# 시아북카페 마곡점 ...완료
# 36
# 선데이키즈클럽 키즈룸 강서
# 키즈카페,실내놀이터
# 선데이키즈클럽 키즈룸 강서 ...완료
# 37
# 롯데백화점 김포공항점
# 백화점
# 롯데백화점 김포공항점 ...완료
# 38
# 물감아놀자
# 키즈카페,실내놀이터
# 물감아놀자 ...완료
# 39
# 챔피언 홈플러스강서점
# 키즈카페,실내놀이터
# 챔피언 홈플러스강서점 ...완료
# 40
# 용문사
# 절,사찰
# 용문사 ...완료
# 41
# 개화산 약사사
# 절,사찰
# 개화산 약사사 ...완료
# 42
# 강서구립 우장산숲속도서관
# 도서관
# 강서구립 우장산숲속도서관 ...완료
# 43
# 무키무키 화곡점
# 키즈카페,실내놀이터
# 무키무키 화곡점 ...완료
# 44
# 봉제산책쉼터
# 도서관
# 봉제산책쉼터 ...완료
# 45
# 킨더마마 더시그니처 롯데백화점 김포공항점
# 키즈카페,실내놀이터
# 킨더마마 더시그니처 롯데백화점 김포공항점 ...완료
# 46
# 보타닉한복
# 한복대여
# 보타닉한복 ...완료
# 47
# 강서구립등빛도서관
# 군구립도서관
# 강서구립등빛도서관 ...완료
# 48
# 미고한복
# 한복대여
# 미고한복 ...완료
# 49
# 서울특별시교육청 강서도서관
# 도서관
# 서울특별시교육청 강서도서관 ...완료
# 50
# 히어로방방키즈카페
# 키즈카페,실내놀이터
# 히어로방방키즈카페 ...완료
# 51
# 에코 롱롱 큐브 서울
# 전시관
# 에코 롱롱 큐브 서울 ...완료
# 52
# 노리파크 화곡점
# 키즈카페,실내놀이터
# 노리파크 화곡점 ...완료
# 53
# 푸른들청소년도서관
# 도서관
# 푸른들청소년도서관 ...완료
# 54
# NSP홀
# 공연장
# NSP홀 ...완료
# 55
# 서울형키즈카페 강서구화곡3동점
# 키즈카페,실내놀이터
# 서울형키즈카페 강서구화곡3동점 ...완료
# 56
# 꿈꾸는어린이도서관
# 어린이도서관
# 꿈꾸는어린이도서관 ...완료
# 57
# 팡팡포레 키즈카페
# 키즈카페,실내놀이터
# 팡팡포레 키즈카페 ...완료
# 58
# 화곡본동시장
# 시장
# 화곡본동시장 ...완료
# 59
# 키즈카페 위드키즈
# 키즈카페,실내놀이터
# 키즈카페 위드키즈 ...완료
# 60
# 송화벽화시장
# 시장
# 송화벽화시장 ...완료
# 61
# 블럭파티플러스 강서점
# 키즈카페,실내놀이터
# 블럭파티플러스 강서점 ...완료
# 62
# 송도아트홀
# 공연장
# 송도아트홀 ...완료
# 63
# 우리별키즈카페 마곡점
# 키즈카페,실내놀이터
# 우리별키즈카페 마곡점 ...완료
# 64
# 토랑이네워터룸 화곡점
# 키즈카페,실내놀이터
# 토랑이네워터룸 화곡점 ...완료
# 65
# 몬스타키즈룸 화곡점
# 키즈카페,실내놀이터
# 몬스타키즈룸 화곡점 ...완료
# 66
# 버니랜드키즈카페
# 키즈카페,실내놀이터
# 버니랜드키즈카페 ...완료
# 67
# 나라문고
# 서점
# 나라문고 ...완료
# 68
# 국립항공박물관 항공도서관
# 전문도서관
# 국립항공박물관 항공도서관 ...완료
# 69
# 쑥스 한복
# 한복대여
# 쑥스 한복 ...완료
# 0
# 강서영어도서관
# 도서관
# 강서영어도서관 ...완료
# 1
# 남부골목시장
# 시장
# 남부골목시장 ...완료
# 2
# 화곡중앙시장
# 시장
# 화곡중앙시장 ...완료
# 3
# 플레이스케이프 롯데몰김포공항점
# 키즈카페,실내놀이터
# 플레이스케이프 롯데몰김포공항점 ...완료
# 4
# 궁산땅굴역사전시관
# 전시관
# 궁산땅굴역사전시관 ...완료
# 5
# 늘솜한복
# 한복대여
# 늘솜한복 ...완료
# 6
# 보광사
# 절,사찰
# 보광사 ...완료
# 7
# 서울식물원 마곡문화관
# 전시관
# 서울식물원 마곡문화관 ...완료
# 8
# 서울형키즈카페 강서구 발산1동점
# 키즈카페,실내놀이터
# 서울형키즈카페 강서구 발산1동점 ...완료
# 9
# 애니팡팡
# 키즈카페,실내놀이터
# 애니팡팡 ...완료
# 10
# 길꽃어린이도서관
# 어린이도서관
# 길꽃어린이도서관 ...완료
# 11
# 안양천합수부
# 공원
# 안양천합수부 ...완료
# 12
# 역마을 작은도서관
# 도서관
# 역마을 작은도서관 ...완료
# 13
# 까치산시장
# 시장
# 까치산시장 ...완료
# 14
# 다시서점
# 독립서점
# 다시서점 ...완료
# 15
# 미타사
# 절,사찰
# 미타사 ...완료
# 16
# 나무곁에 서서
# 독립서점
# 나무곁에 서서 ...완료
# 17
# 더아메리칸라이브러리인서울
# 전문도서관
# 더아메리칸라이브러리인서울 ...완료
# 18
# 게으른 오후
# 서점
# 게으른 오후 ...완료
# 19
# 등촌7종합사회복지관 장난감도서관
# 전문도서관
# 등촌7종합사회복지관 장난감도서관 ...완료
# 20
# 볏골어린이공원
# 공원
# 볏골어린이공원 ...완료
# 21
# 꿈자람책놀이터 작은도서관
# 도서관
# 꿈자람책놀이터 작은도서관 ...완료
# 22
# 허준마을 작은도서관
# 도서관
# 허준마을 작은도서관 ...완료
# 23
# LG유플러스 Gallery C
# 갤러리,화랑
# LG유플러스 Gallery C ...완료
# 24
# 갤러리블라썸
# 갤러리,화랑
# 갤러리블라썸 ...완료
# 25
# 독립서점 화서가
# 독립서점
# 독립서점 화서가 ...완료
# 26
# 책마당 SH작은도서관
# 도서관
# 책마당 SH작은도서관 ...완료
# 27
# 안골어린이공원
# 공원
# 안골어린이공원 ...완료
# 28
# 예솔어린이공원
# 공원
# 예솔어린이공원 ...완료
# 29
# 판개목쉼터
# 공원
# 판개목쉼터 ...완료
# 30
# list index out of range
# ERROR!ERROR!ERROR!
# 31
# list index out of range
# ERROR!ERROR!ERROR!
# 32
# list index out of range
# ERROR!ERROR!ERROR!
# 33
# list index out of range
# ERROR!ERROR!ERROR!
# 34
# list index out of range
# ERROR!ERROR!ERROR!
# 35
# list index out of range
# ERROR!ERROR!ERROR!
# 36
# list index out of range
# ERROR!ERROR!ERROR!
# 37
# list index out of range
# ERROR!ERROR!ERROR!
# 38
# list index out of range
# ERROR!ERROR!ERROR!
# 39
# list index out of range
# ERROR!ERROR!ERROR!
# 40
# list index out of range
# ERROR!ERROR!ERROR!
# 41
# list index out of range
# ERROR!ERROR!ERROR!
# 42
# list index out of range
# ERROR!ERROR!ERROR!
# 43
# list index out of range
# ERROR!ERROR!ERROR!
# 44
# list index out of range
# ERROR!ERROR!ERROR!
# 45
# list index out of range
# ERROR!ERROR!ERROR!
# 46
# list index out of range
# ERROR!ERROR!ERROR!
# 47
# list index out of range
# ERROR!ERROR!ERROR!
# 48
# list index out of range
# ERROR!ERROR!ERROR!
# 49
# list index out of range
# ERROR!ERROR!ERROR!
# 50
# list index out of range
# ERROR!ERROR!ERROR!
# 51
# list index out of range
# ERROR!ERROR!ERROR!
# 52
# list index out of range
# ERROR!ERROR!ERROR!
# 53
# list index out of range
# ERROR!ERROR!ERROR!
# 54
# list index out of range
# ERROR!ERROR!ERROR!
# 55
# list index out of range
# ERROR!ERROR!ERROR!
# 56
# list index out of range
# ERROR!ERROR!ERROR!
# 57
# list index out of range
# ERROR!ERROR!ERROR!
# 58
# list index out of range
# ERROR!ERROR!ERROR!
# 59
# list index out of range
# ERROR!ERROR!ERROR!
# 60
# list index out of range
# ERROR!ERROR!ERROR!
# 61
# list index out of range
# ERROR!ERROR!ERROR!
# 62
# list index out of range
# ERROR!ERROR!ERROR!
# 63
# list index out of range
# ERROR!ERROR!ERROR!
# 64
# list index out of range
# ERROR!ERROR!ERROR!
# 65
# list index out of range
# ERROR!ERROR!ERROR!
# 66
# list index out of range
# ERROR!ERROR!ERROR!
# 67
# list index out of range
# ERROR!ERROR!ERROR!
# 68
# list index out of range
# ERROR!ERROR!ERROR!
# 69
# list index out of range
# ERROR!ERROR!ERROR!
# 0
# 강서영어도서관
# 도서관
# 강서영어도서관 ...완료
# 1
# 남부골목시장
# 시장
# 남부골목시장 ...완료
# 2
# 화곡중앙시장
# 시장
# 화곡중앙시장 ...완료
# 3
# 플레이스케이프 롯데몰김포공항점
# 키즈카페,실내놀이터
# 플레이스케이프 롯데몰김포공항점 ...완료
# 4
# 궁산땅굴역사전시관
# 전시관
# 궁산땅굴역사전시관 ...완료
# 5
# 늘솜한복
# 한복대여
# 늘솜한복 ...완료
# 6
# 보광사
# 절,사찰
# 보광사 ...완료
# 7
# 서울식물원 마곡문화관
# 전시관
# 서울식물원 마곡문화관 ...완료
# 8
# 서울형키즈카페 강서구 발산1동점
# 키즈카페,실내놀이터
# 서울형키즈카페 강서구 발산1동점 ...완료
# 9
# 애니팡팡
# 키즈카페,실내놀이터
# 애니팡팡 ...완료
# 10
# 길꽃어린이도서관
# 어린이도서관
# 길꽃어린이도서관 ...완료
# 11
# 안양천합수부
# 공원
# 안양천합수부 ...완료
# 12
# 역마을 작은도서관
# 도서관
# 역마을 작은도서관 ...완료
# 13
# 까치산시장
# 시장
# 까치산시장 ...완료
# 14
# 다시서점
# 독립서점
# 다시서점 ...완료
# 15
# 미타사
# 절,사찰
# 미타사 ...완료
# 16
# 나무곁에 서서
# 독립서점
# 나무곁에 서서 ...완료
# 17
# 더아메리칸라이브러리인서울
# 전문도서관
# 더아메리칸라이브러리인서울 ...완료
# 18
# 게으른 오후
# 서점
# 게으른 오후 ...완료
# 19
# 등촌7종합사회복지관 장난감도서관
# 전문도서관
# 등촌7종합사회복지관 장난감도서관 ...완료
# 20
# 볏골어린이공원
# 공원
# 볏골어린이공원 ...완료
# 21
# 꿈자람책놀이터 작은도서관
# 도서관
# 꿈자람책놀이터 작은도서관 ...완료
# 22
# 허준마을 작은도서관
# 도서관
# 허준마을 작은도서관 ...완료
# 23
# LG유플러스 Gallery C
# 갤러리,화랑
# LG유플러스 Gallery C ...완료
# 24
# 갤러리블라썸
# 갤러리,화랑
# 갤러리블라썸 ...완료
# 25
# 독립서점 화서가
# 독립서점
# 독립서점 화서가 ...완료
# 26
# 책마당 SH작은도서관
# 도서관
# 책마당 SH작은도서관 ...완료
# 27
# 안골어린이공원
# 공원
# 안골어린이공원 ...완료
# 28
# 예솔어린이공원
# 공원
# 예솔어린이공원 ...완료
# 29
# 판개목쉼터
# 공원
# 판개목쉼터 ...완료
# 30
# list index out of range
# ERROR!ERROR!ERROR!
# 31
# list index out of range
# ERROR!ERROR!ERROR!
# 32
# list index out of range
# ERROR!ERROR!ERROR!
# 33
# list index out of range
# ERROR!ERROR!ERROR!
# 34
# list index out of range
# ERROR!ERROR!ERROR!
# 35
# list index out of range
# ERROR!ERROR!ERROR!
# 36
# list index out of range
# ERROR!ERROR!ERROR!
# 37
# list index out of range
# ERROR!ERROR!ERROR!
# 38
# list index out of range
# ERROR!ERROR!ERROR!
# 39
# list index out of range
# ERROR!ERROR!ERROR!
# 40
# list index out of range
# ERROR!ERROR!ERROR!
# 41
# list index out of range
# ERROR!ERROR!ERROR!
# 42
# list index out of range
# ERROR!ERROR!ERROR!
# 43
# list index out of range
# ERROR!ERROR!ERROR!
# 44
# list index out of range
# ERROR!ERROR!ERROR!
# 45
# list index out of range
# ERROR!ERROR!ERROR!
# 46
# list index out of range
# ERROR!ERROR!ERROR!
# 47
# list index out of range
# ERROR!ERROR!ERROR!
# 48
# list index out of range
# ERROR!ERROR!ERROR!
# 49
# list index out of range
# ERROR!ERROR!ERROR!
# 50
# list index out of range
# ERROR!ERROR!ERROR!
# 51
# list index out of range
# ERROR!ERROR!ERROR!
# 52
# list index out of range
# ERROR!ERROR!ERROR!
# 53
# list index out of range
# ERROR!ERROR!ERROR!
# 54
# list index out of range
# ERROR!ERROR!ERROR!
# 55
# list index out of range
# ERROR!ERROR!ERROR!
# 56
# list index out of range
# ERROR!ERROR!ERROR!
# 57
# list index out of range
# ERROR!ERROR!ERROR!
# 58
# list index out of range
# ERROR!ERROR!ERROR!
# 59
# list index out of range
# ERROR!ERROR!ERROR!
# 60
# list index out of range
# ERROR!ERROR!ERROR!
# 61
# list index out of range
# ERROR!ERROR!ERROR!
# 62
# list index out of range
# ERROR!ERROR!ERROR!
# 63
# list index out of range
# ERROR!ERROR!ERROR!
# 64
# list index out of range
# ERROR!ERROR!ERROR!
# 65
# list index out of range
# ERROR!ERROR!ERROR!
# 66
# list index out of range
# ERROR!ERROR!ERROR!
# 67
# list index out of range
# ERROR!ERROR!ERROR!
# 68
# list index out of range
# ERROR!ERROR!ERROR!
# 69
# list index out of range
# ERROR!ERROR!ERROR!
# [데이터 수집 완료]
# 소요 시간 : 720.0119454860687
