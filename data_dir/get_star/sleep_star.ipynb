# %%
#이름이랑 별점만 크롤링
import json
import time
from time import sleep
import csv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

def search_food(key):
    
    cafe_list = []
    
    url = 'https://map.naver.com/v5/search'
    driver = webdriver.Chrome()  # 드라이버
    driver.get(url)
    key_word = "서울" + key + ' 숙소'  # 검색어

    # css 찾을때 까지 10초대기
    def time_wait(num, code):
        try:
            wait = WebDriverWait(driver, num).until(
                EC.presence_of_element_located((By.CSS_SELECTOR, code)))
        except:
            print(code, '태그를 찾지 못하였습니다.')
            driver.quit()
        return wait

    # frame 변경 메소드
    def switch_frame(frame):
        driver.switch_to.default_content()  # frame 초기화
        driver.switch_to.frame(frame)  # frame 변경

    # 페이지 다운
    def page_down(num):
        body = driver.find_element(By.CSS_SELECTOR, 'body')
        body.click()
        for i in range(num):
            body.send_keys(Keys.PAGE_DOWN)

    # css를 찾을때 까지 10초 대기
    time_wait(10, 'div.input_box > input.input_search')

    # (1) 검색창 찾기
    search = driver.find_element(By.CSS_SELECTOR, 'div.input_box > input.input_search')
    search.send_keys(key_word)  # 검색어 입력
    search.send_keys(Keys.ENTER)  # 엔터버튼 누르기

    sleep(1)

    # (2) frame 변경
    switch_frame('searchIframe')
    page_down(40)
    sleep(3)

    # 가게 리스트
    shop_list = driver.find_elements(By.CSS_SELECTOR, 'li.VLTHu')
    # 페이지 리스트
    next_btn = driver.find_elements(By.CSS_SELECTOR, '.zRM9F> a')

    # dictionary 생성
    shop_dict = {'가게정보': []}
    # 시작시간
    start = time.time()
    print('[크롤링 시작...]')
    
    print(shop_list)

    # 크롤링 (페이지 리스트 만큼)
    for btn in range(len(next_btn))[1:]:  # next_btn[0] = 이전 페이지 버튼 무시 -> [1]부터 시작
        parking_list = driver.find_elements(By.CSS_SELECTOR, 'li.VLTHu')
        names = driver.find_elements(By.CSS_SELECTOR, '.YwYLL')  # (3) 장소명
        types = driver.find_elements(By.CSS_SELECTOR, '.YzBgS')  # (4) 장소 유형

        for data in range(len(shop_list)):  # 가게 리스트 만큼
            print(data)
            
            #real_star = star[data].text
            #real_star = str(real_star).split("\n")[1]
            #print(real_star)
            #if float(real_star) < 4.3:
            #    continue

            sleep(1)
            try:

                # (3) 가게명 가져오기
                shop_name = str(names[data].text)
                print(shop_name)

                # (4) 유형
                shop_type = str(types[data].text)
                print(shop_type)
                
                #(5) 별점
                #real_star = star[data].text
                #real_star = str(real_star).split("\n")[1]
                #print(real_star)
                
                tmp = [shop_name]
                cafe_list.append(tmp)
                
                print(f'{shop_name} ...완료')

                sleep(1)

            except Exception as e:
                print(e)
                print('ERROR!' * 3)

                sleep(1)

        # 다음 페이지 버튼 누를 수 없으면 종료
        if not next_btn[-1].is_enabled():
            break

        if names[-1]:  # 마지막이면 다음버튼 클릭
            next_btn[-1].click()

            sleep(2)

        else:
            print('페이지 인식 못함')
            break

    print('[데이터 수집 완료]\n소요 시간 :', time.time() - start)
    driver.quit()  # 작업이 끝나면 창을 닫는다.

    index_final = len(cafe_list) // 2
    cafe_list = cafe_list[0:index_final]
    
    return cafe_list

##############################################################################

regions = ["종로구", "중구", "용산구", "성동구", "광진구", "동대문구", "중랑구", "성북구", "강북구", "도봉구", "노원구", "은평구", "서대문구", "마포구", "양천구", 
           "강서구", "구로구", "금천구", "영등포구", "동작구", "관악구", "서초구", "강남구", "송파구", "강동구"]

    
#1, 2 // 15, 16 // len(regions)
for i in range(15, 16):
    filename = "./out_sleep/out_" + str(i) + "_sleep.csv"
    f = open(filename, 'w', encoding='utf-8', newline='')
    writer = csv.writer(f)
    writer.writerows(search_food(regions[i]))
    f.close()
# Out:
# The chromedriver version (128.0.6613.137) detected in PATH at c:\Users\kk21\Desktop\TRIPER\chromedriver.exe might not be compatible with the detected chrome version (129.0.6668.90); currently, chromedriver 129.0.6668.91 is recommended for chrome 129.*, so it is advised to delete the driver in PATH and retry
# [크롤링 시작...]
# [<selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.130")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.131")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.132")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.133")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.134")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.135")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.136")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.137")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.138")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.139")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.140")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.141")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.142")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.143")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.144")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.145")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.146")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.147")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.148")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.149")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9450F535297A9DF16.e.150")>, <selenium.webdriver.remote.webelement.WebElement (session="0e658319ee11604fb153d5af14386622", element="f.455D6CBD4D50FAD5ABF959A130E79EC0.d.4A886D9F6C1794B9 ...
# 0
# 메이필드호텔
# 호텔
# 메이필드호텔 ...완료
# 1
# 코트야드 메리어트 서울 보타닉파크 호텔
# 호텔
# 코트야드 메리어트 서울 보타닉파크 호텔 ...완료
# 2
# SR호텔 마곡
# 호텔
# SR호텔 마곡 ...완료
# 3
# 제이케이블라썸 호텔
# 호텔
# 제이케이블라썸 호텔 ...완료
# 4
# 인터시티365
# 호텔
# 인터시티365 ...완료
# 5
# 더퍼스트스테이 호텔
# 호텔
# 더퍼스트스테이 호텔 ...완료
# 6
# 골든서울호텔
# 호텔
# 골든서울호텔 ...완료
# 7
# 롯데시티호텔 김포공항
# 호텔
# 롯데시티호텔 김포공항 ...완료
# 8
# 마곡롯데캐슬르웨스트
# 생활형숙박시설
# 마곡롯데캐슬르웨스트 ...완료
# 9
# 로얄스퀘어 호텔
# 호텔
# 로얄스퀘어 호텔 ...완료
# 10
# 호텔 엠펠리체
# 호텔
# 호텔 엠펠리체 ...완료
# 11
# 나이아가라 호텔
# 호텔
# 나이아가라 호텔 ...완료
# 12
# 국제청소년센터 유스호스텔
# 호스텔
# 국제청소년센터 유스호스텔 ...완료
# 13
# 시선 호텔
# 호텔
# 시선 호텔 ...완료
# 14
# 티파니호텔
# 모텔
# 티파니호텔 ...완료
# 15
# 골든호텔
# 모텔
# 골든호텔 ...완료
# 16
# 브라운도트 강서구청점
# 호텔
# 브라운도트 강서구청점 ...완료
# 17
# 컴앤스테이 강서지점
# 호텔
# 컴앤스테이 강서지점 ...완료
# 18
# 칼튼호텔
# 모텔
# 칼튼호텔 ...완료
# 19
# 호텔에스
# 호텔
# 호텔에스 ...완료
# 20
# 다산하우스
# 게스트하우스
# 다산하우스 ...완료
# 21
# 어거스트
# 호텔
# 어거스트 ...완료
# 22
# 심플스테이
# 모텔
# 심플스테이 ...완료
# 23
# 나나하우스
# 게스트하우스
# 나나하우스 ...완료
# 24
# 호텔 볼 서울
# 호텔
# 호텔 볼 서울 ...완료
# 25
# 호텔앤
# 모텔
# 호텔앤 ...완료
# 26
# 이지호텔
# 호텔
# 이지호텔 ...완료
# 27
# 이청정
# 호텔
# 이청정 ...완료
# 28
# 호텔야자 강서구청점
# 모텔
# 호텔야자 강서구청점 ...완료
# 29
# 뱅크모텔
# 모텔
# 뱅크모텔 ...완료
# 30
# 호텔드어반
# 호텔
# 호텔드어반 ...완료
# 31
# VL르웨스트(2025년10월예정)
# 생활형숙박시설
# VL르웨스트(2025년10월예정) ...완료
# 32
# 스타호텔
# 모텔
# 스타호텔 ...완료
# 33
# N호텔
# 호텔
# N호텔 ...완료
# 34
# 거기모텔
# 모텔
# 거기모텔 ...완료
# 35
# 스테이림
# 민박
# 스테이림 ...완료
# 36
# 호텔A
# 기타숙박업
# 호텔A ...완료
# 37
# MS호텔
# 모텔
# MS호텔 ...완료
# 38
# 킴스테이9
# 게스트하우스
# 킴스테이9 ...완료
# 39
# 해담채 스테이
# 호텔
# 해담채 스테이 ...완료
# 40
# 호텔티제이
# 호텔
# 호텔티제이 ...완료
# 41
# 앨리스넥스트도어호텔
# 모텔
# 앨리스넥스트도어호텔 ...완료
# 42
# HOTEL THEME
# 모텔
# HOTEL THEME ...완료
# 43
# 유니온호텔
# 호텔
# 유니온호텔 ...완료
# 44
# 드림호텔
# 호텔
# 드림호텔 ...완료
# 45
# 썸모텔
# 모텔
# 썸모텔 ...완료
# 46
# 모텔플라워
# 모텔
# 모텔플라워 ...완료
# 47
# 리츠 모텔
# 모텔
# 리츠 모텔 ...완료
# 48
# 시네마모텔
# 모텔
# 시네마모텔 ...완료
# 49
# 호텔딘
# 모텔
# 호텔딘 ...완료
# 50
# 웨일로 서울김포공항점
# 펜션
# 웨일로 서울김포공항점 ...완료
# 51
# 등촌모텔세븐
# 모텔
# 등촌모텔세븐 ...완료
# 52
# CL모텔
# 모텔
# CL모텔 ...완료
# 53
# 테르모 호텔
# 모텔
# 테르모 호텔 ...완료
# 54
# 호텔 디아망
# 호텔
# 호텔 디아망 ...완료
# 55
# 매일하임 화곡하임
# 모텔
# 매일하임 화곡하임 ...완료
# 56
# 스테이240
# 민박
# 스테이240 ...완료
# 57
# 러쉬호텔
# 모텔
# 러쉬호텔 ...완료
# 58
# 대우모텔
# 모텔
# 대우모텔 ...완료
# 59
# 샤르망모텔
# 모텔
# 샤르망모텔 ...완료
# 60
# 머큐어 서울마곡
# 호텔
# 머큐어 서울마곡 ...완료
# 61
# 호텔야자 호텔앤 화곡점
# 모텔
# 호텔야자 호텔앤 화곡점 ...완료
# 62
# 서울모텔
# 모텔
# 서울모텔 ...완료
# 63
# 나비앤서울게스트하우스
# 게스트하우스
# 나비앤서울게스트하우스 ...완료
# 64
# 러브레터모텔
# 모텔
# 러브레터모텔 ...완료
# 65
# 설레임모텔
# 모텔
# 설레임모텔 ...완료
# 66
# 평화장모텔
# 기타숙박업
# 평화장모텔 ...완료
# 67
# 초콜렛호텔
# 호텔
# 초콜렛호텔 ...완료
# 68
# 에어포트 게스트하우스
# 게스트하우스
# 에어포트 게스트하우스 ...완료
# 69
# 소설스미스
# 모텔
# 소설스미스 ...완료
# 0
# 호텔그린월드
# 호텔
# 호텔그린월드 ...완료
# 1
# 르아브르
# 모텔
# 르아브르 ...완료
# 2
# 서울여관
# 여관
# 서울여관 ...완료
# 3
# 소담스레 목동점
# 레지던스
# 소담스레 목동점 ...완료
# 4
# 알프스모텔
# 모텔
# 알프스모텔 ...완료
# 5
# 쟈스민 모텔
# 모텔
# 쟈스민 모텔 ...완료
# 6
# 스테이홀리
# 기타숙박업
# 스테이홀리 ...완료
# 7
# RANG
# 모텔
# RANG ...완료
# 8
# 화곡 샤르망
# 모텔
# 화곡 샤르망 ...완료
# 9
# 케이투모텔
# 모텔
# 케이투모텔 ...완료
# 10
# 쉐르빌모텔
# 모텔
# 쉐르빌모텔 ...완료
# 11
# 화곡 구름성
# 모텔
# 화곡 구름성 ...완료
# 12
# 제일모텔 화곡역
# 여관
# 제일모텔 화곡역 ...완료
# 13
# 탑모텔
# 모텔
# 탑모텔 ...완료
# 14
# 한강라이다호텔앙코르모델하우스
# 호텔
# 한강라이다호텔앙코르모델하우스 ...완료
# 15
# 팰리스모텔
# 모텔
# 팰리스모텔 ...완료
# 16
# 다우스모텔
# 모텔
# 다우스모텔 ...완료
# 17
# 호텔쎄븐
# 호텔
# 호텔쎄븐 ...완료
# 18
# 리치모텔
# 모텔
# 리치모텔 ...완료
# 19
# 스테이세렌디피티
# 민박
# 스테이세렌디피티 ...완료
# 20
# 리버풀모텔
# 모텔
# 리버풀모텔 ...완료
# 21
# 모텔Goodday
# 모텔
# 모텔Goodday ...완료
# 22
# 랑뷰티크호텔
# 호텔
# 랑뷰티크호텔 ...완료
# 23
# 리치모텔
# 모텔
# 리치모텔 ...완료
# 24
# 한성여관
# 여관
# 한성여관 ...완료
# 25
# 커플모텔
# 모텔
# 커플모텔 ...완료
# 26
# 모모스테이
# 기타숙박업
# 모모스테이 ...완료
# 27
# 코스테이호텔
# 호텔
# 코스테이호텔 ...완료
# 28
# 제일모텔
# 모텔
# 제일모텔 ...완료
# 29
# 호텔볼콤마
# 모텔
# 호텔볼콤마 ...완료
# 30
# 대림장여관
# 여관
# 대림장여관 ...완료
# 31
# 여우잠
# 모텔
# 여우잠 ...완료
# 32
# 코지웰
# 게스트하우스
# 코지웰 ...완료
# 33
# 솔라스테이
# 민박
# 솔라스테이 ...완료
# 34
# 요니아파트먼트
# 게스트하우스
# 요니아파트먼트 ...완료
# 35
# 언니네
# 게스트하우스
# 언니네 ...완료
# 36
# 일쏠레모텔
# 모텔
# 일쏠레모텔 ...완료
# 37
# 에코호텔
# 호텔
# 에코호텔 ...완료
# 38
# 모텔노블레스
# 모텔
# 모텔노블레스 ...완료
# 39
# 보보모텔
# 모텔
# 보보모텔 ...완료
# 40
# 금성여관
# 여관
# 금성여관 ...완료
# 41
# 일심장
# 여관
# 일심장 ...완료
# 42
# 대호여관
# 여관
# 대호여관 ...완료
# 43
# 공원관광호텔
# 호텔
# 공원관광호텔 ...완료
# 44
# 청솔여관
# 여관
# 청솔여관 ...완료
# 45
# 그린피아모텔
# 모텔
# 그린피아모텔 ...완료
# 46
# 삼부장
# 여관
# 삼부장 ...완료
# 47
# 뉴테르모 호텔
# 모텔
# 뉴테르모 호텔 ...완료
# 48
# Cozy Room
# 게스트하우스
# Cozy Room ...완료
# 49
# 금강여관
# 여관
# 금강여관 ...완료
# 50
# 필호스텔
# 호스텔
# 필호스텔 ...완료
# 51
# 스마일 홈스테이
# 홈스테이
# 스마일 홈스테이 ...완료
# 52
# 게스트하우스 더 레드
# 게스트하우스
# 게스트하우스 더 레드 ...완료
# 53
# 오슬로모텔
# 모텔
# 오슬로모텔 ...완료
# 54
# 로얄모텔
# 모텔
# 로얄모텔 ...완료
# 55
# 아리아모텔
# 모텔
# 아리아모텔 ...완료
# 56
# 정스테이
# 민박
# 정스테이 ...완료
# 57
# 리베모텔
# 모텔
# 리베모텔 ...완료
# 58
# 디오스모텔
# 모텔
# 디오스모텔 ...완료
# 59
# 서울 엔젤 B&B
# 게스트하우스
# 서울 엔젤 B&B ...완료
# 60
# 엘하우스(L House)
# 홈스테이
# 엘하우스(L House) ...완료
# 61
# 청아장모텔
# 모텔
# 청아장모텔 ...완료
# 62
# 제일장
# 여관
# 제일장 ...완료
# 63
# 오투모텔
# 모텔
# 오투모텔 ...완료
# 64
# 화곡 보성모텔
# 모텔
# 화곡 보성모텔 ...완료
# 65
# 빅토리아모텔
# 모텔
# 빅토리아모텔 ...완료
# 66
# 플라이서울
# 기타숙박업
# 플라이서울 ...완료
# 67
# 앤프라2
# 호텔
# 앤프라2 ...완료
# 68
# RnR House
# 게스트하우스
# RnR House ...완료
# 69
# 골든프라자모텔
# 모텔
# 골든프라자모텔 ...완료
# 0
# 쉬리모텔
# 모텔
# 쉬리모텔 ...완료
# 1
# 힐모텔
# 모텔
# 힐모텔 ...완료
# 2
# 탐라영재관 남자사감실
# 기타숙박업
# 탐라영재관 남자사감실 ...완료
# 3
# 럭셔리모텔
# 모텔
# 럭셔리모텔 ...완료
# 4
# 스테이샾101
# 기타숙박업
# 스테이샾101 ...완료
# 5
# 에스더스테이
# 생활형숙박시설
# 에스더스테이 ...완료
# 6
# 난지캠핑장
# 캠핑,야영장
# 난지캠핑장 ...완료
# 7
# 노을캠핑장
# 캠핑,야영장
# 노을캠핑장 ...완료
# 8
# 호텔 마리나베이서울
# 호텔
# 호텔 마리나베이서울 ...완료
# 9
# 라마다앙코르 바이윈덤 김포한강호텔
# 호텔
# 라마다앙코르 바이윈덤 김포한강호텔 ...완료
# 10
# 스탠포드호텔코리아
# 호텔
# 스탠포드호텔코리아 ...완료
# 11
# 호텔 마리나베이 서울 아라
# 호텔
# 호텔 마리나베이 서울 아라 ...완료
# 12
# 우아테파티앤스튜디오
# 셀프,대여스튜디오
# 우아테파티앤스튜디오 ...완료
# 13
# 한빛고시원
# 고시원,고시텔
# 한빛고시원 ...완료
# 14
# 두리생태공원오토캠핑장
# 캠핑,야영장
# 두리생태공원오토캠핑장 ...완료
# 15
# 고양호텔유지
# 호텔
# 고양호텔유지 ...완료
# 16
# 포스타호텔
# 호텔
# 포스타호텔 ...완료
# 17
# 스테이25
# 모텔
# 스테이25 ...완료
# 18
# 호텔 라르 김포
# 호텔
# 호텔 라르 김포 ...완료
# 19
# 럭스호텔
# 모텔
# 럭스호텔 ...완료
# 20
# 상록고시텔 화곡동점
# 고시원,고시텔
# 상록고시텔 화곡동점 ...완료
# 21
# 호텔브릿지
# 호텔
# 호텔브릿지 ...완료
# 22
# 호텔 아로조
# 호텔
# 호텔 아로조 ...완료
# 23
# 오목교 코업레지던스
# 레지던스
# 오목교 코업레지던스 ...완료
# 24
# 노을공원반려견동반캠핑장
# 캠핑,야영장
# 노을공원반려견동반캠핑장 ...완료
# 25
# ADO hotel
# 호텔
# ADO hotel ...완료
# 26
# 잠모텔
# 모텔
# 잠모텔 ...완료
# 27
# 머스트스테이모텔 신정네거리역점
# 모텔
# 머스트스테이모텔 신정네거리역점 ...완료
# 28
# 감나무골
# 한식
# 감나무골 ...완료
# 29
# 우리들고시텔
# 고시원,고시텔
# 우리들고시텔 ...완료
# 30
# 휘닉스아일랜드 예약
# 콘도,리조트
# 휘닉스아일랜드 예약 ...완료
# 31
# 사이버호텔
# 모텔
# 사이버호텔 ...완료
# 32
# 스탠포드호텔 연회
# 호텔
# 스탠포드호텔 연회 ...완료
# 33
# Y Road 135
# 게스트하우스
# Y Road 135 ...완료
# 34
# 롯데캐슬르웨스트공인중개사사무소
# 중개업
# 롯데캐슬르웨스트공인중개사사무소 ...완료
# 35
# 밸류플레이스 강서구청점
# 고시원,고시텔
# 밸류플레이스 강서구청점 ...완료
# 36
# 모텔메종
# 모텔
# 모텔메종 ...완료
# 37
# 호텔 리베라
# 모텔
# 호텔 리베라 ...완료
# 38
# 트리피카
# 광고대행
# 트리피카 ...완료
# 39
# 다온공인중개사사무소
# 중개업
# 다온공인중개사사무소 ...완료
# 40
# 캠프호텔
# 호텔
# 캠프호텔 ...완료
# 41
# 문래여관
# 모텔
# 문래여관 ...완료
# 42
# 호텔 샤또
# 호텔
# 호텔 샤또 ...완료
# 43
# 마리호텔
# 호텔
# 마리호텔 ...완료
# 44
# 모카호텔
# 호텔
# 모카호텔 ...완료
# 45
# 스위스모텔
# 모텔
# 스위스모텔 ...완료
# 46
# A모텔
# 모텔
# A모텔 ...완료
# 47
# 시즈더데이
# 소프트웨어개발
# 시즈더데이 ...완료
# 48
# 월드파크모텔
# 모텔
# 월드파크모텔 ...완료
# 49
# 호텔 르네
# 모텔
# 호텔 르네 ...완료
# 50
# 스카이시티오피스텔
# 호텔
# 스카이시티오피스텔 ...완료
# 51
# 이브모텔
# 모텔
# 이브모텔 ...완료
# 52
# 호텔사이버
# 호텔
# 호텔사이버 ...완료
# 53
# 호텔럭스
# 호텔
# 호텔럭스 ...완료
# 54
# 알브호텔
# 모텔
# 알브호텔 ...완료
# 55
# 양천토마토
# 모텔
# 양천토마토 ...완료
# 56
# 로즈모텔
# 모텔
# 로즈모텔 ...완료
# 57
# 시타딘한리버서울호텔
# 호텔
# 시타딘한리버서울호텔 ...완료
# 58
# 노바루스 관광 호텔
# 모텔
# 노바루스 관광 호텔 ...완료
# 59
# 서울 스테이 목동하우스
# 게스트하우스
# 서울 스테이 목동하우스 ...완료
# 60
# 마루관광호텔
# 호텔
# 마루관광호텔 ...완료
# 61
# 프린스
# 모텔
# 프린스 ...완료
# 62
# 돈키호텔
# 모텔
# 돈키호텔 ...완료
# 63
# 에스모텔
# 모텔
# 에스모텔 ...완료
# 64
# 가예호스텔
# 호스텔
# 가예호스텔 ...완료
# 65
# 호텔3&4
# 여관
# 호텔3&4 ...완료
# 66
# 토마토모텔
# 모텔
# 토마토모텔 ...완료
# 67
# 에소르모텔
# 모텔
# 에소르모텔 ...완료
# 68
# 어번 게스트 하우스
# 게스트하우스
# 어번 게스트 하우스 ...완료
# 69
# 더센트럴호텔
# 호텔
# 더센트럴호텔 ...완료
# 0
# 양천베스트
# 모텔
# 양천베스트 ...완료
# 1
# 원스테이
# 모텔
# 원스테이 ...완료
# 2
# 청춘여관
# 여관
# 청춘여관 ...완료
# 3
# 모텔초이스
# 모텔
# 모텔초이스 ...완료
# 4
# 리버모텔
# 모텔
# 리버모텔 ...완료
# 5
# 팔레스모텔
# 모텔
# 팔레스모텔 ...완료
# 6
# 청수장모텔
# 모텔
# 청수장모텔 ...완료
# 7
# 호텔AROZO
# 호텔
# 호텔AROZO ...완료
# 8
# 가온호스텔
# 호스텔
# 가온호스텔 ...완료
# 9
# 라온
# 민박
# 라온 ...완료
# 10
# 서울H
# 게스트하우스
# 서울H ...완료
# 11
# 상상그린게스트하우스
# 게스트하우스
# 상상그린게스트하우스 ...완료
# 12
# 젠모텔
# 모텔
# 젠모텔 ...완료
# 13
# 용스 하우스
# 게스트하우스
# 용스 하우스 ...완료
# 14
# 크리스탈모텔
# 모텔
# 크리스탈모텔 ...완료
# 15
# 황실여관
# 여관
# 황실여관 ...완료
# 16
# 호텔린넨서비스
# 호텔
# 호텔린넨서비스 ...완료
# 17
# 토마토모텔
# 모텔
# 토마토모텔 ...완료
# 18
# 로진호스텔
# 호스텔
# 로진호스텔 ...완료
# 19
# 라인모텔
# 모텔
# 라인모텔 ...완료
# 20
# 태양장여관
# 여관
# 태양장여관 ...완료
# 21
# 유토피아
# 모텔
# 유토피아 ...완료
# 22
# 크리스탈여관
# 모텔
# 크리스탈여관 ...완료
# 23
# 고려여관
# 여관
# 고려여관 ...완료
# 24
# 마이홈
# 게스트하우스
# 마이홈 ...완료
# 25
# 왕실장
# 여관
# 왕실장 ...완료
# 26
# 토마토모텔
# 모텔
# 토마토모텔 ...완료
# 27
# 서울파티룸 해밍
# 이벤트,파티
# 서울파티룸 해밍 ...완료
# 28
# 레지던스 오름 프리미엄 원룸텔 목동역점
# 고시원,고시텔
# 레지던스 오름 프리미엄 원룸텔 목동역점 ...완료
# 29
# 하우스테이 신정
# 임대업
# 하우스테이 신정 ...완료
# 30
# 담음레지던스 원룸
# 주택건설
# 담음레지던스 원룸 ...완료
# 31
# 레저스테이션
# 여행사
# 레저스테이션 ...완료
# 32
# 스테이오더앤페이
# 인터넷상거래
# 스테이오더앤페이 ...완료
# 33
# 워킹시니어
# 요양원,요양센터
# 워킹시니어 ...완료
# 34
# 노을2숙소 개방화장실
# 화장실
# 노을2숙소 개방화장실 ...완료
# 35
# 위파트먼트
# 임대업
# 위파트먼트 ...완료
# 36
# 삼풍종합건축사사무소
# 건축설계
# 삼풍종합건축사사무소 ...완료
# 37
# 수도보일러배관녹물청소제거전문,어린이집유치원학교숙박업소
# 배관,냉난방공사
# 수도보일러배관녹물청소제거전문,어린이집유치원학교숙박업소 ...완료
# 38
# list index out of range
# ERROR!ERROR!ERROR!
# 39
# list index out of range
# ERROR!ERROR!ERROR!
# 40
# list index out of range
# ERROR!ERROR!ERROR!
# 41
# list index out of range
# ERROR!ERROR!ERROR!
# 42
# list index out of range
# ERROR!ERROR!ERROR!
# 43
# list index out of range
# ERROR!ERROR!ERROR!
# 44
# list index out of range
# ERROR!ERROR!ERROR!
# 45
# list index out of range
# ERROR!ERROR!ERROR!
# 46
# list index out of range
# ERROR!ERROR!ERROR!
# 47
# list index out of range
# ERROR!ERROR!ERROR!
# 48
# list index out of range
# ERROR!ERROR!ERROR!
# 49
# list index out of range
# ERROR!ERROR!ERROR!
# 50
# list index out of range
# ERROR!ERROR!ERROR!
# 51
# list index out of range
# ERROR!ERROR!ERROR!
# 52
# list index out of range
# ERROR!ERROR!ERROR!
# 53
# list index out of range
# ERROR!ERROR!ERROR!
# 54
# list index out of range
# ERROR!ERROR!ERROR!
# 55
# list index out of range
# ERROR!ERROR!ERROR!
# 56
# list index out of range
# ERROR!ERROR!ERROR!
# 57
# list index out of range
# ERROR!ERROR!ERROR!
# 58
# list index out of range
# ERROR!ERROR!ERROR!
# 59
# list index out of range
# ERROR!ERROR!ERROR!
# 60
# list index out of range
# ERROR!ERROR!ERROR!
# 61
# list index out of range
# ERROR!ERROR!ERROR!
# 62
# list index out of range
# ERROR!ERROR!ERROR!
# 63
# list index out of range
# ERROR!ERROR!ERROR!
# 64
# list index out of range
# ERROR!ERROR!ERROR!
# 65
# list index out of range
# ERROR!ERROR!ERROR!
# 66
# list index out of range
# ERROR!ERROR!ERROR!
# 67
# list index out of range
# ERROR!ERROR!ERROR!
# 68
# list index out of range
# ERROR!ERROR!ERROR!
# 69
# list index out of range
# ERROR!ERROR!ERROR!
# 0
# 양천베스트
# 모텔
# 양천베스트 ...완료
# 1
# 원스테이
# 모텔
# 원스테이 ...완료
# 2
# 청춘여관
# 여관
# 청춘여관 ...완료
# 3
# 모텔초이스
# 모텔
# 모텔초이스 ...완료
# 4
# 리버모텔
# 모텔
# 리버모텔 ...완료
# 5
# 팔레스모텔
# 모텔
# 팔레스모텔 ...완료
# 6
# 청수장모텔
# 모텔
# 청수장모텔 ...완료
# 7
# 호텔AROZO
# 호텔
# 호텔AROZO ...완료
# 8
# 가온호스텔
# 호스텔
# 가온호스텔 ...완료
# 9
# 라온
# 민박
# 라온 ...완료
# 10
# 서울H
# 게스트하우스
# 서울H ...완료
# 11
# 상상그린게스트하우스
# 게스트하우스
# 상상그린게스트하우스 ...완료
# 12
# 젠모텔
# 모텔
# 젠모텔 ...완료
# 13
# 용스 하우스
# 게스트하우스
# 용스 하우스 ...완료
# 14
# 크리스탈모텔
# 모텔
# 크리스탈모텔 ...완료
# 15
# 황실여관
# 여관
# 황실여관 ...완료
# 16
# 호텔린넨서비스
# 호텔
# 호텔린넨서비스 ...완료
# 17
# 토마토모텔
# 모텔
# 토마토모텔 ...완료
# 18
# 로진호스텔
# 호스텔
# 로진호스텔 ...완료
# 19
# 라인모텔
# 모텔
# 라인모텔 ...완료
# 20
# 태양장여관
# 여관
# 태양장여관 ...완료
# 21
# 유토피아
# 모텔
# 유토피아 ...완료
# 22
# 크리스탈여관
# 모텔
# 크리스탈여관 ...완료
# 23
# 고려여관
# 여관
# 고려여관 ...완료
# 24
# 마이홈
# 게스트하우스
# 마이홈 ...완료
# 25
# 왕실장
# 여관
# 왕실장 ...완료
# 26
# 토마토모텔
# 모텔
# 토마토모텔 ...완료
# 27
# 서울파티룸 해밍
# 이벤트,파티
# 서울파티룸 해밍 ...완료
# 28
# 레지던스 오름 프리미엄 원룸텔 목동역점
# 고시원,고시텔
# 레지던스 오름 프리미엄 원룸텔 목동역점 ...완료
# 29
# 하우스테이 신정
# 임대업
# 하우스테이 신정 ...완료
# 30
# 담음레지던스 원룸
# 주택건설
# 담음레지던스 원룸 ...완료
# 31
# 레저스테이션
# 여행사
# 레저스테이션 ...완료
# 32
# 스테이오더앤페이
# 인터넷상거래
# 스테이오더앤페이 ...완료
# 33
# 워킹시니어
# 요양원,요양센터
# 워킹시니어 ...완료
# 34
# 노을2숙소 개방화장실
# 화장실
# 노을2숙소 개방화장실 ...완료
# 35
# 위파트먼트
# 임대업
# 위파트먼트 ...완료
# 36
# 삼풍종합건축사사무소
# 건축설계
# 삼풍종합건축사사무소 ...완료
# 37
# 수도보일러배관녹물청소제거전문,어린이집유치원학교숙박업소
# 배관,냉난방공사
# 수도보일러배관녹물청소제거전문,어린이집유치원학교숙박업소 ...완료
# 38
# list index out of range
# ERROR!ERROR!ERROR!
# 39
# list index out of range
# ERROR!ERROR!ERROR!
# 40
# list index out of range
# ERROR!ERROR!ERROR!
# 41
# list index out of range
# ERROR!ERROR!ERROR!
# 42
# list index out of range
# ERROR!ERROR!ERROR!
# 43
# list index out of range
# ERROR!ERROR!ERROR!
# 44
# list index out of range
# ERROR!ERROR!ERROR!
# 45
# list index out of range
# ERROR!ERROR!ERROR!
# 46
# list index out of range
# ERROR!ERROR!ERROR!
# 47
# list index out of range
# ERROR!ERROR!ERROR!
# 48
# list index out of range
# ERROR!ERROR!ERROR!
# 49
# list index out of range
# ERROR!ERROR!ERROR!
# 50
# list index out of range
# ERROR!ERROR!ERROR!
# 51
# list index out of range
# ERROR!ERROR!ERROR!
# 52
# list index out of range
# ERROR!ERROR!ERROR!
# 53
# list index out of range
# ERROR!ERROR!ERROR!
# 54
# list index out of range
# ERROR!ERROR!ERROR!
# 55
# list index out of range
# ERROR!ERROR!ERROR!
# 56
# list index out of range
# ERROR!ERROR!ERROR!
# 57
# list index out of range
# ERROR!ERROR!ERROR!
# 58
# list index out of range
# ERROR!ERROR!ERROR!
# 59
# list index out of range
# ERROR!ERROR!ERROR!
# 60
# list index out of range
# ERROR!ERROR!ERROR!
# 61
# list index out of range
# ERROR!ERROR!ERROR!
# 62
# list index out of range
# ERROR!ERROR!ERROR!
# 63
# list index out of range
# ERROR!ERROR!ERROR!
# 64
# list index out of range
# ERROR!ERROR!ERROR!
# 65
# list index out of range
# ERROR!ERROR!ERROR!
# 66
# list index out of range
# ERROR!ERROR!ERROR!
# 67
# list index out of range
# ERROR!ERROR!ERROR!
# 68
# list index out of range
# ERROR!ERROR!ERROR!
# 69
# list index out of range
# ERROR!ERROR!ERROR!
# [데이터 수집 완료]
# 소요 시간 : 721.5291502475739
